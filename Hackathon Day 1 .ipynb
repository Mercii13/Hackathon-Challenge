# %% [markdown]
# Bus fare determination - Que 1 Day 1 -
# Today's Date Stored in Variable "Date"

# %%
Day = str(input("Enter day of week"))
Date = int(input("Enter date"))
Month = str(input("Enter month of year"))
Year = int(input("Enter calendar year"))
Date = Day, Date, Month, Year
print (Date)
# Out:
# Enter day of weekSarturday
# Enter date9
# Enter month of yearJuly
# Enter calendar year2022
# ('Sarturday', 9, 'July', 2022)

# %% [markdown]
# Bus fare Determination - Que 2 Day 1 -
# Todays Date to Get Name of Day

# %%
import datetime

dir(datetime)

gvrstrftime = datetime.datetime.today()

print (gvr.strftime("%A, %B, %d, %Y" ))
# Out:
# Saturday, July, 09, 2022

# %%
import datetime
date =datetime.datetime.today()
print (date)
# Out:
# 2022-07-09 18:16:07.540533

# %% [markdown]
# Bus fare Determination - Que 3 Day 1

# %%
a = str(input("Enter a"))
b = str(input("Enter b"))
c = str(input("Enter c"))
if a == "Monday" or "Tuesday" or "Wednesday" or "Thursday" or "Friday":
  print ("Fare is 100")
if b== "Saturday":
  print("Fare is 60")
if c == "Sunday":
  print("Fare is 80")
  Details =
# Out:
# Enter aTuesday
# Enter bWednesday
# Enter cThursday
# Fare is 100

# %%
day = datetime.datetime.today()
now = date.weekday();
if now <=5:
  print ("Fare is 100")
if now ==6:
    print("Fare is 60")
elif now ==7:
      print("Fare is 80")
# Out:
# Fare is 100

# %% [markdown]
# Day One - Task Two

# %%
wall_space = float (input("Enter square feet painted"))
sample_sqft = int (115)
sqft_painted_per_hour = float (14.375)
paint_cost = float(input("Enter cost paint"))
gallons_used = float (input("Enter gallons used"))
labour_hours = float(input("Enter square feet painted") /"sqft_painted_per_hour"
labour_hourly_charge = float(20.00)
total_cost = gallon_used * gallon_cost + labour_hours * labour_hourly_charge
print(total_cost)
# Out:
#   File "<ipython-input-44-6d6dbba36bd3>", line 8
#     labour_hourly_charge = float(20.00)
#                        ^
# SyntaxError: invalid syntax

# %%
wall_space = float (input("Enter square feet painted"))
sample_sqft = int (115)
sqft_painted_per_hour = float (14.375)
paint_cost = float(input("Enter cost paint"))
gallons_used = float (input("Enter gallons used"))
labour_hours = float(input("Enter labour hours")
hourly_charge = float(20.00)
total_cost = gallon_used * gallon_cost + labour_hours * labour_hourly_charge
print(total_cost)
# Out:
#   File "<ipython-input-48-27be74407934>", line 7
#     hourly_charge = float(20.00)
#                 ^
# SyntaxError: invalid syntax
